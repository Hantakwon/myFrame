# %%
# !pip install -q -U google-genai

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client(api_key="AIzaSyDuokiyJKPl9arMZi3sy9OHgBp-uKeTrMY")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="AI가 어떻게 작동하는지 몇 마디로 설명하세요"
)

print(response.text)
# Out:
# AI는 **데이터를 학습**하여 **패턴**을 찾아내고, 이를 바탕으로 **결정**을 내리거나 **예측**을 하는 기술입니다.

# %%
from google import genai
from google.genai import types


prompt = """
Alice, Bob, and Carol each live in a different house on the same street: red, green, and blue.
The person who lives in the red house owns a cat.
Bob does not live in the green house.
Carol owns a dog.
The green house is to the left of the red house.
Alice does not own a cat.
Who lives in each house, and what pet do they own?
"""

client = genai.Client(api_key="AIzaSyDuokiyJKPl9arMZi3sy9OHgBp-uKeTrMY")
response = client.models.generate_content(
  model="gemini-2.5-flash", # 사용 모델
  contents=prompt, 
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True # 사고(Thinking) 사용을 True로
    )
  )
)

for part in response.candidates[0].content.parts:
  if not part.text:
    continue
  if part.thought:
    print("Thought summary:")
    print(part.text)
    print()
  else:
    print("Answer:")
    print(part.text)
    print()
# Out:
# Thought summary:
# **My Thought Process to Solve the Logic Puzzle:**
#
# Okay, here's how I'm thinking about this logic puzzle. My main goal is to figure out which person lives in which house and owns which pet. I know there are three people, three houses (red, green, blue), and three pets (cat, dog, and a third, implied pet).
#
# I started by listing the known entities: Alice, Bob, Carol; the red, green, and blue houses; and the cat, dog, and the third pet. Then I set up a table to keep track of the relationships, but I quickly realized a direct approach of listing out the people, houses, and pets with notes next to them was the most clear way.
#
# ...

# %%
from google import genai
from google.genai import types


prompt = """
Alice, Bob, and Carol each live in a different house on the same street: red, green, and blue.
The person who lives in the red house owns a cat.
Bob does not live in the green house.
Carol owns a dog.
The green house is to the left of the red house.
Alice does not own a cat.
Who lives in each house, and what pet do they own?
"""

client = genai.Client(api_key="AIzaSyDuokiyJKPl9arMZi3sy9OHgBp-uKeTrMY")
response = client.models.generate_content(
  model="gemini-2.5-flash", # 사용 모델
  contents=prompt, 
)


print(response.text)
# Out:
# Let's break down the clues step by step to solve this puzzle:
#
# 1.  **The person who lives in the red house owns a cat.**
#     *   Constraint: Red House = Cat Owner
#
# 2.  **Alice does not own a cat.** (Clue 5)
#     *   From (1) and (2): Alice does not live in the Red House.
#
# 3.  **Carol owns a dog.** (Clue 3)
#     *   From (1) and (3): Since the Red House owner has a cat, Carol (who owns a dog) cannot live in the Red House.
#
# 4.  **Combining deductions for the Red House:**
#     *   Alice doesn't live in the Red House.
#     *   Carol doesn't live in the Red House.
#     *   Therefore, by elimination, **Bob must live in the Red House.**
#     *   Since Bob lives in the Red House and the Red House owner has a cat, **Bob owns a cat.**
#
# 5.  **Pets for everyone:**
#     *   Bob owns a cat. (From 4)
#     *   Carol owns a dog. (Clue 3)
# ...
